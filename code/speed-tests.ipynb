# %%
import importlib 
m = importlib.import_module(".model", "src")
from matplotlib import pyplot as plt
import numpy as np
import cProfile

# %%
eta = 3/5
gamma = 1
beta = 0.5

# %%
H = m.GrowingHypergraph()
H.add_edge((0, 1))

cmd = \
"""
for _ in range(50000):
    H.sample_edge(eta, gamma, beta)
"""

# %%
cProfile.run(cmd)
# Out:
#          3458929 function calls in 2.764 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.036    0.036    2.764    2.764 <string>:2(<module>)
#    483763    0.640    0.000    0.719    0.000 hypergraph.py:23(__getitem__)
#    150670    0.064    0.000    0.064    0.000 hypergraph.py:29(__setitem__)
#     51005    0.012    0.000    0.012    0.000 hypergraph.py:314(edges)
#    255231    0.069    0.000    0.094    0.000 hypergraph.py:319(num_nodes)
#     51005    0.018    0.000    0.024    0.000 hypergraph.py:343(num_edges)
#     50000    0.389    0.000    1.249    0.000 hypergraph.py:488(add_edge)
#     50000    0.040    0.000    1.288    0.000 model.py:13(add_edge)
#     50000    0.464    0.000    2.728    0.000 model.py:16(sample_edge)
#     51005    0.024    0.000    0.036    0.000 numeric.py:1878(isscalar)
#     51005    0.030    0.000    0.030    0.000 reportviews.py:156(__contains__)
#     51005    0.056    0.000    0.143    0.000 reportviews.py:640(members)
#         1    0.000    0.000    2.764    2.764 {built-in method builtins.exec}
#     51005    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#    458246    0.048    0.000    0.048    0.000 {built-in method builtins.len}
#     50000    0.009    0.000    0.009    0.000 {built-in method builtins.next}
#    483763    0.079    0.000    0.079    0.000 {function IDDict.__getitem__ at 0x2aaab7c3b1f0}
#    574140    0.110    0.000    0.110    0.000 {method 'add' of 'set' objects}
#     51005    0.083    0.000    0.083    0.000 {method 'binomial' of 'numpy.random.mtrand.RandomState' objects}
#     51005    0.026    0.000    0.026    0.000 {method 'copy' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     50000    0.008    0.000    0.008    0.000 {method 'keys' of 'dict' objects}
#     51005    0.080    0.000    0.116    0.000 {method 'poisson' of 'numpy.random.mtrand.RandomState' objects}
#    191852    0.088    0.000    0.088    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#    102216    0.372    0.000    0.372    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#     50000    0.008    0.000    0.008    0.000 {method 'update' of 'dict' objects}

# %%
n = 1000
choices = range(n)

# %%
# %timeit np.random.randint(n)
# Out:
# 2.53 µs ± 149 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
